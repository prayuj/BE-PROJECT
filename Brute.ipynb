# %%
from datetime import datetime
def program(target):
    start_time = datetime.now()
    letters = '''abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOP 
    QRSTUVWXYZ 1234567890, .-;:_!"#%&/()=?@${[]}'''
    string = ""
    count = 0
    for t in target:
        for letter in letters:
            if letter == t:
                print(string)
                string += letter
                break

    print(string)
    end_time = datetime.now()
    print("Time Taken = ",(end_time-start_time).microseconds)
# if __name__ == '__main__': 
#     sentences = ["Hello there!", "My name is Prayuj", "I am in BE COMPS"]
#     for sentence in sentences:
#         program(sentence)

# %%
string = "Python3 program to create target string, starting from random string using Genetic Algorithm"
program(string)
# Out:
# P
# Py
# Pyt
# Pyth
# Pytho
# Python
# Python3
# Python3
# Python3 p
# Python3 pr
# Python3 pro
# Python3 prog
# Python3 progr
# Python3 progra
# Python3 program
# Python3 program
# Python3 program t
# Python3 program to
# Python3 program to
# Python3 program to c
# Python3 program to cr
# Python3 program to cre
# Python3 program to crea
# Python3 program to creat
# Python3 program to create
# Python3 program to create
# Python3 program to create t
# Python3 program to create ta
# Python3 program to create tar
# Python3 program to create targ
# Python3 program to create targe
# Python3 program to create target
# Python3 program to create target
# Python3 program to create target s
# Python3 program to create target st
# Python3 program to create target str
# Python3 program to create target stri
# Python3 program to create target strin
# Python3 program to create target string
# Python3 program to create target string,
# Python3 program to create target string,
# ...
