# %%
# Python3 program to create target string, starting from 
# random string using Genetic Algorithm 

import random 
from datetime import datetime
# Number of individuals in each generation 
POPULATION_SIZE = 100

# Valid genes 
GENES = '''abcdefghijklmnopqrstuvwxyzABCDEFGHIJKLMNOP 
QRSTUVWXYZ 1234567890, .-;:_!"#%&/()=?@${[]}'''

# Target string to be generated 
TARGET = "Hi There"

class Individual(object): 
    ''' 
    Class representing individual in population 
    '''
    def __init__(self, chromosome): 
        self.chromosome = chromosome 
        self.fitness = self.cal_fitness() 

    @classmethod
    def mutated_genes(self): 
        ''' 
        create random genes for mutation 
        '''
        global GENES 
        gene = random.choice(GENES) 
        return gene 

    @classmethod
    def create_gnome(self): 
        ''' 
        create chromosome or string of genes 
        '''
        global TARGET 
        gnome_len = len(TARGET) 
        return [self.mutated_genes() for _ in range(gnome_len)] 

    def mate(self, par2): 
        ''' 
        Perform mating and produce new offspring 
        '''

        # chromosome for offspring 
        child_chromosome = [] 
        for gp1, gp2 in zip(self.chromosome, par2.chromosome):	 

            # random probability 
            prob = random.random() 

            # if prob is less than 0.45, insert gene 
            # from parent 1 
            if prob < 0.45: 
                child_chromosome.append(gp1) 

            # if prob is between 0.45 and 0.90, insert 
            # gene from parent 2 
            elif prob < 0.90: 
                child_chromosome.append(gp2) 

            # otherwise insert random gene(mutate), 
            # for maintaining diversity 
            else: 
                child_chromosome.append(self.mutated_genes()) 

        # create new Individual(offspring) using 
        # generated chromosome for offspring 
        return Individual(child_chromosome) 

    def cal_fitness(self): 
        ''' 
        Calculate fittness score, it is the number of 
        characters in string which differ from target 
        string. 
        '''
        global TARGET 
        fitness = 0
        for gs, gt in zip(self.chromosome, TARGET): 
            if gs != gt: fitness+= 1
        return fitness 

# Driver code 
def main(): 
    time = datetime.now()
    global POPULATION_SIZE 

    #current generation 
    generation = 1

    found = False
    population = [] 

    # create initial population 
    for _ in range(POPULATION_SIZE): 
                gnome = Individual.create_gnome() 
                population.append(Individual(gnome)) 

    while not found: 

        # sort the population in increasing order of fitness score 
        population = sorted(population, key = lambda x:x.fitness) 

        # if the individual having lowest fitness score ie. 
        # 0 then we know that we have reached to the target 
        # and break the loop 
        if population[0].fitness <= 0: 
            found = True
            break

        # Otherwise generate new offsprings for new generation 
        new_generation = [] 

        # Perform Elitism, that mean 10% of fittest population 
        # goes to the next generation 
        s = int((10*POPULATION_SIZE)/1000000) 
        new_generation.extend(population[:s]) 

    # From 50% of fittest population, Individuals 
            # will mate to produce offspring 
        s = int((90*POPULATION_SIZE)/100) 
        for _ in range(s): 
            parent1 = random.choice(population[:50]) 
            parent2 = random.choice(population[:50]) 
            child = parent1.mate(parent2) 
            new_generation.append(child) 

        population = new_generation 
        print("Generation: {}\tString: {}\tFitness: {}".format(generation,"".join(population[0].chromosome),population[0].fitness)) 
        
        generation += 1

    
    print("Generation: {}\tString: {}\tFitness: {}".format(generation,"".join(population[0].chromosome),population[0].fitness)) 
    print("Time Taken = ",(datetime.now()-time).microseconds)
    
if __name__ == '__main__': 
    main()
# Out:
# Generation: 1	String: S3I(9 {}	Fitness: 8
# Generation: 2	String: p[ %?)&,	Fitness: 7
# Generation: 3	String: Fi3
# Gtr(	Fitness: 6
# Generation: 4	String: 4A Th)9P	Fitness: 5
# Generation: 5	String: CX5T6)T-	Fitness: 7
# Generation: 6	String: 4i T_htP	Fitness: 5
# Generation: 7	String: p[ h4H&e	Fitness: 6
# Generation: 8	String: "i m?2t=	Fitness: 6
# Generation: 9	String: Qi :4TC.	Fitness: 6
# Generation: 10	String: Ui JOaV9	Fitness: 6
# Generation: 11	String: g
#  The7$	Fitness: 4
# Generation: 12	String: :i mO?be	Fitness: 5
# Generation: 13	String: "i qC-ra	Fitness: 5
# Generation: 14	String: pi 1f"W6	Fitness: 6
# Generation: 15	String: "i}1her$	Fitness: 4
# Generation: 16	String: :i mhere	Fitness: 2
# Generation: 17	String: 7i st7rv	Fitness: 5
# Generation: 18	String: @i T:ere	Fitness: 2
# Generation: 19	String: Ji There	Fitness: 1
# Generation: 20	String: Ji mhere	Fitness: 2
# Generation: 21	String: si $here	Fitness: 2
# Generation: 22	String: JU,mhere	Fitness: 4
# Generation: 23	String: }i(1here	Fitness: 3
# Generation: 24	String: p,-There	Fitness: 3
# Generation: 25	String: ti rher(	Fitness: 3
# Generation: 26	String: zz TGere	Fitness: 3
# Generation: 27	String: sq TheVY	Fitness: 4
# Generation: 28	String: ki Cherd	Fitness: 3
# Generation: 29	String: vi Ghere	Fitness: 2
# Generation: 30	String: siwCher(	Fitness: 4
# Generation: 31	String: Mi There	Fitness: 1
# Generation: 32	String: Ni There	Fitness: 1
# Generation: 33	String: 5i _Oer-	Fitness: 4
# Generation: 34	String: Kq?The5e	Fitness: 4
# Generation: 35	String: vi Theje	Fitness: 2
# Generation: 36	String: vif[here	Fitness: 3
# Generation: 37	String: vi ThQr%	Fitness: 3
# Generation: 38	String: 9i Dhere	Fitness: 2
# Generation: 39	String: 9y Ther;	Fitness: 3
# Generation: 40	String: wi There	Fitness: 1
# Generation: 41	String: Ei There	Fitness: 1
# Generation: 42	String: 8ibThere	Fitness: 2
# Generation: 43	String: Ei There	Fitness: 1
# Generation: 44	String: %i TheBe	Fitness: 2
# Generation: 45	String: vi Nhere	Fitness: 2
# Generation: 46	String: Ei There	Fitness: 1
# Generation: 47	String: vi Thgue	Fitness: 3
# Generation: 48	String: D$h;here	Fitness: 4
# Generation: 49	String: bi There	Fitness: 1
# Generation: 50	String: Vi There	Fitness: 1
# Generation: 51	String: Di TherL	Fitness: 2
# Generation: 52	String: ps Tg#rJ	Fitness: 5
# Generation: 53	String: Ui TherA	Fitness: 2
# Generation: 54	String: Di There	Fitness: 1
# Generation: 55	String: $irTherP	Fitness: 3
# Generation: 56	String: Ei ThCke	Fitness: 3
# Generation: 57	String: eE There	Fitness: 2
# Generation: 58	String: qi There	Fitness: 1
# Generation: 59	String: ei There	Fitness: 1
# Generation: 60	String: ei The(e	Fitness: 2
# Generation: 61	String: ciO1here	Fitness: 3
# Generation: 62	String: ei#Uhere	Fitness: 3
# Generation: 63	String: EiyThMre	Fitness: 3
# Generation: 64	String: Mi T?ere	Fitness: 2
# Generation: 65	String: xi T;ere	Fitness: 2
# Generation: 66	String: Ri There	Fitness: 1
# Generation: 67	String: "i Theee	Fitness: 2
# Generation: 68	String: xi There	Fitness: 1
# Generation: 69	String: qi There	Fitness: 1
# Generation: 70	String: xi Thera	Fitness: 2
# Generation: 71	String: .i There	Fitness: 1
# Generation: 72	String: pi The]e	Fitness: 2
# Generation: 73	String: Vi ,herc	Fitness: 3
# Generation: 74	String: xi uhDre	Fitness: 3
# Generation: 75	String: &i There	Fitness: 1
# Generation: 76	String: Di=There	Fitness: 2
# Generation: 77	String: Di ThDre	Fitness: 2
# Generation: 78	String: #iH
# here	Fitness: 3
# Generation: 79	String: wi There	Fitness: 1
# Generation: 80	String: Ei There	Fitness: 1
# Generation: 81	String: Ei NheIe	Fitness: 3
# Generation: 82	String: 8iKThere	Fitness: 2
# Generation: 83	String: Qi Th3rm	Fitness: 3
# Generation: 84	String: Ji The{e	Fitness: 2
# Generation: 85	String: ti Thwre	Fitness: 2
# Generation: 86	String: gi nhere	Fitness: 2
# Generation: 87	String: ti There	Fitness: 1
# Generation: 88	String: ii Tg-re	Fitness: 3
# Generation: 89	String:
# i Thebe	Fitness: 2
# Generation: 90	String: Ei There	Fitness: 1
# Generation: 91	String: s@ There	Fitness: 2
# Generation: 92	String: Oi2There	Fitness: 2
# Generation: 93	String: Ti /here	Fitness: 2
# Generation: 94	String: tiGThere	Fitness: 2
# Generation: 95	String: 7i ThTrd	Fitness: 3
# Generation: 96	String: ki Jhere	Fitness: 2
# Generation: 97	String: Ei T2ere	Fitness: 2
# Generation: 98	String: Li Th7oe	Fitness: 3
# Generation: 99	String: @i Dhere	Fitness: 2
# Generation: 100	String: tK Tkere	Fitness: 3
# Generation: 101	String: [] T5erK	Fitness: 4
# Generation: 102	String: si The,e	Fitness: 2
# Generation: 103	String: Qi lhere	Fitness: 2
# Generation: 104	String: 1i There	Fitness: 1
# Generation: 105	String: Ci There	Fitness: 1
# Generation: 106	String: Hi There	Fitness: 0
# Time Taken =  151595

# %%
a = datetime.now() - datetime.now()

# %%
a.microseconds
# Out:
# 0
